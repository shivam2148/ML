# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df1=pd.read_csv('data_final.csv')

# %%
df1.head()
# Out:
#    observation  feature   price
# 0         0.44     0.68  511.14
# 1         0.99     0.23  717.10
# 2         0.84     0.29  607.91
# 3         0.28     0.45  270.40
# 4         0.07     0.83  289.88

# %%
df1.shape
# Out:
# (100, 3)

# %%
# 100 rows and 3 column 
df1.isnull().sum()
# Out:
# observation    0
# feature        0
# price          0
# dtype: int64

# %%
# no null present 
df1.describe()
# Out:
#        observation     feature        price
# count   100.000000  100.000000   100.000000
# mean      0.550300    0.501700   554.214600
# std       0.293841    0.307124   347.312796
# min       0.010000    0.000000    42.080000
# 25%       0.300000    0.230000   278.172500
# 50%       0.570000    0.485000   514.285000
# 75%       0.822500    0.760000   751.752500
# max       1.000000    0.990000  1563.820000

# %%
sns.pairplot(df1)

# %%
x=df1.iloc[:,:-1].values
y=df1.iloc[:,:-1].values

# %%
x.shape , y.shape
# Out:
# ((100, 2), (100, 2))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 3)
x_poly = poly_reg.fit_transform(x_train)
lg = LinearRegression()
lg.fit(x_poly,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
data=LinearRegression()
data.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred1 = lg1.predict(poly_reg.fit_transform(x_test))
y_pred1
# Out:
# array([[0.68, 0.13],
#        [0.3 , 0.08],
#        [0.84, 0.29],
#        [0.06, 0.42],
#        [0.3 , 0.99],
#        [0.22, 0.46],
#        [0.47, 0.66],
#        [0.92, 0.03],
#        [0.63, 0.58],
#        [0.99, 0.13],
#        [0.96, 0.25],
#        [0.89, 0.68],
#        [0.79, 0.94],
#        [0.9 , 0.94],
#        [0.57, 0.43],
#        [0.62, 0.17],
#        [0.78, 0.85],
#        [0.04, 0.52],
#        [0.91, 0.53],
#        [0.43, 0.89]])

# %%
y_pred = data.predict(x_test)
y_pred
# Out:
# array([[0.68, 0.13],
#        [0.3 , 0.08],
#        [0.84, 0.29],
#        [0.06, 0.42],
#        [0.3 , 0.99],
#        [0.22, 0.46],
#        [0.47, 0.66],
#        [0.92, 0.03],
#        [0.63, 0.58],
#        [0.99, 0.13],
#        [0.96, 0.25],
#        [0.89, 0.68],
#        [0.79, 0.94],
#        [0.9 , 0.94],
#        [0.57, 0.43],
#        [0.62, 0.17],
#        [0.78, 0.85],
#        [0.04, 0.52],
#        [0.91, 0.53],
#        [0.43, 0.89]])

# %%
plt.scatter(y_pred,y_test,color='red')
plt.plot(y_pred,y_test,color='green')

# %% [markdown]
# # All the points are on the regression line
# # therefore we can create a model which can #predict price accurately
